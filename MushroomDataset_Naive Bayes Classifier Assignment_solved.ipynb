# %%
# Import necessary libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print('Importing is done')
# Out:
# Importing is done

# %%
# load the dataset

df = pd.read_csv('mushroom_cleaned.csv')
print('Loading is done')
# Out:
# Loading is done

# %%
df
# Out:
#        cap-diameter  cap-shape  gill-attachment  gill-color  stem-height  \
# 0              1372          2                2          10     3.807467
# 1              1461          2                2          10     3.807467
# 2              1371          2                2          10     3.612496
# 3              1261          6                2          10     3.787572
# 4              1305          6                2          10     3.711971
# ...             ...        ...              ...         ...          ...
# 54030            73          5                3           2     0.887740
# 54031            82          2                3           2     1.186164
# 54032            82          5                3           2     0.915593
# 54033            79          2                3           2     1.034963
# 54034            72          5                3           2     1.158311
#
#        stem-width  stem-color    season  class
# ...

# %%
# Summarizing Dataset:
# We can see that there are 54035 rows & 9 columns in tne above dataset.
# The dataset has details of the produce of mushrooms with different characteristics & likewise seggregation of them into classes.
# The dataset has categorised the mushroom on basis of 'cap-diameter', 'cap-shape', 'gill-attachment', 'gill-color', 'stem-height', 'stem-width', 'stem-color' & 'season'.
# Finally all these details help seggregate the relevant mushroom as class 1 (good) or class 0 (not good).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54035 entries, 0 to 54034
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   cap-diameter     54035 non-null  int64
#  1   cap-shape        54035 non-null  int64
#  2   gill-attachment  54035 non-null  int64
#  3   gill-color       54035 non-null  int64
#  4   stem-height      54035 non-null  float64
#  5   stem-width       54035 non-null  int64
#  6   stem-color       54035 non-null  int64
#  7   season           54035 non-null  float64
#  8   class            54035 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 3.7 MB

# %%
df.describe()
# Out:
#        cap-diameter     cap-shape  gill-attachment    gill-color  \
# count  54035.000000  54035.000000     54035.000000  54035.000000
# mean     567.257204      4.000315         2.142056      7.329509
# std      359.883763      2.160505         2.228821      3.200266
# min        0.000000      0.000000         0.000000      0.000000
# 25%      289.000000      2.000000         0.000000      5.000000
# 50%      525.000000      5.000000         1.000000      8.000000
# 75%      781.000000      6.000000         4.000000     10.000000
# max     1891.000000      6.000000         6.000000     11.000000
#
#         stem-height    stem-width    stem-color        season         class
# count  54035.000000  54035.000000  54035.000000  54035.000000  54035.000000
# mean       0.759110   1051.081299      8.418062      0.952163      0.549181
# std        0.650969    782.056076      3.262078      0.305594      0.497580
# min        0.000426      0.000000      0.000000      0.027372      0.000000
# ...

# %%
len(df)
# Out:
# 54035

# %%
df.head(5)
# Out:
#    cap-diameter  cap-shape  gill-attachment  gill-color  stem-height  \
# 0          1372          2                2          10     3.807467
# 1          1461          2                2          10     3.807467
# 2          1371          2                2          10     3.612496
# 3          1261          6                2          10     3.787572
# 4          1305          6                2          10     3.711971
#
#    stem-width  stem-color    season  class
# 0        1545          11  1.804273      1
# 1        1557          11  1.804273      1
# 2        1566          11  1.804273      1
# 3        1566          11  1.804273      1
# 4        1464          11  0.943195      1

# %%
df.tail(5)
# Out:
#        cap-diameter  cap-shape  gill-attachment  gill-color  stem-height  \
# 54030            73          5                3           2     0.887740
# 54031            82          2                3           2     1.186164
# 54032            82          5                3           2     0.915593
# 54033            79          2                3           2     1.034963
# 54034            72          5                3           2     1.158311
#
#        stem-width  stem-color    season  class
# 54030         569          12  0.943195      1
# 54031         490          12  0.943195      1
# 54032         584          12  0.888450      1
# 54033         491          12  0.888450      1
# 54034         492          12  0.888450      1

# %%
df.dtypes
# Out:
# cap-diameter         int64
# cap-shape            int64
# gill-attachment      int64
# gill-color           int64
# stem-height        float64
# stem-width           int64
# stem-color           int64
# season             float64
# class                int64
# dtype: object

# %%
df['class'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
# Pre-processing the dataset

# %%
# Checking the null values

df.isnull().sum()
# Out:
# cap-diameter       0
# cap-shape          0
# gill-attachment    0
# gill-color         0
# stem-height        0
# stem-width         0
# stem-color         0
# season             0
# class              0
# dtype: int64

# %%
df.isnull().sum().max
# Out:
# <bound method Series.max of cap-diameter       0
# cap-shape          0
# gill-attachment    0
# gill-color         0
# stem-height        0
# stem-width         0
# stem-color         0
# season             0
# class              0
# dtype: int64>

# %%
# From the above it is clear that we do not have any null values in this dataset. so now we can proceed further.

# %%
# We do not perform any encoding as the entire dataset is in data type as interger/ numerical.

# %%
# Data Visualisation

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# 1) Plotting chart of distribution of features

# Setting up the matplotlib figure
plt.figure(figsize=(15, 10))

# %%
# a> Visualize the distribution of 'cap-diameter'
plt.subplot(1,1,1)
sns.histplot(df['cap-diameter'], kde=True)
plt.title('Distribution of Cap Diameter')
# Out:
# Text(0.5, 1.0, 'Distribution of Cap Diameter')

# %%
# The above shows data representation of the mushroom with different cap diameter.
# The more big size the cap, best if the quality of mushroom.

# %%
# b> Visualize the distribution of 'cap-shape'
plt.subplot(1,1,1)
sns.countplot(x='cap-shape', data=df)
plt.title('Distribution of Cap Shape')
# Out:
# Text(0.5, 1.0, 'Distribution of Cap Shape')

# %%
# This data shows count of cap shape of the mushroom head.
# Better cap shape can be achieved under control environment adding to quality of mushroom.

# %%
# c> Visualize the distribution of 'gill-attachment'
plt.subplot(1,1,1)
sns.countplot(x='gill-attachment', data=df)
plt.title('Distribution of Gill Attachment')
# Out:
# Text(0.5, 1.0, 'Distribution of Gill Attachment')

# %%
# Big size gill attachment leads to better reproduction process of mushrooms as it helps to release spores in downward direction.

# %%
# d> Visualize the distribution of 'gill-color'
plt.subplot(1,1,1)
sns.countplot(x='gill-color', data=df)
plt.title('Distribution of Gill Color')
# Out:
# Text(0.5, 1.0, 'Distribution of Gill Color')

# %%
# This data shows count of different gill colours available for the mushrooms in the dataset.
# Ideally this is for naked eye to seggregate good quality mushrooms from other ones.
# Best is a faint pinkish hue when you hold it in the light. If it's deep dark black or wet looking, the mushroom is past its prime

# %%
# e> Visualize the distribution of 'stem-height'
plt.subplot(1,1,1)
sns.histplot(df['stem-height'], kde=True)
plt.title('Distribution of Stem Height')
# Out:
# Text(0.5, 1.0, 'Distribution of Stem Height')

# %%
# The above chart shows produce with different stem height.
# This can be one of the factors for quality mushrooms.

# %%
# f> Visualize the distribution of 'stem-width'
plt.subplot(1,1,1)
sns.histplot(df['stem-width'], kde=True)
plt.title('Distribution of Stem Width')
plt.tight_layout()
plt.show()

# %%
# The above chart shows produce with different stem width.
# This is one of the factors for quality mushrooms.

# %%
# 2) Correlation matrix
plt.figure(figsize=(12, 8))
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
# From above chart we can see that there is direct co-relation between cap diameter, stem width VS class of mushroom.

# %%
# Pairplot to visualize relationships of all features VS class.

sns.pairplot(df, hue='class', markers=["o", "s"])
plt.suptitle('Pairplot of Features Colored by Class', y=1.02)
plt.show()

# %%
df.dtypes
# Out:
# cap-diameter         int64
# cap-shape            int64
# gill-attachment      int64
# gill-color           int64
# stem-height        float64
# stem-width           int64
# stem-color           int64
# season             float64
# class                int64
# dtype: object

# %%
# Bar chart of all features versus class (target column)

# Convert 'class' to string for better readability in the plot
df['class'] = df['class'].astype(str)

# List of features to plot
features = ['cap-diameter', 'cap-shape', 'gill-attachment', 'gill-color', 'stem-height', 'stem-width', 'stem-color', 'season']

# Plotting bar plots for each feature versus class
for feature in features:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=feature, hue='class', data=df, palette='viridis')
    plt.title(f'Bar Plot of {feature.replace("-", " ").capitalize()} vs Class')
    plt.xlabel(feature.replace("-", " ").capitalize())
    plt.ylabel('Count')
    plt.legend(title='Class')
    plt.show()

# %%
# The above chart helps us understand the quality of mushroom produce falling under class 1 or 0, depending upon their characeristics.

# %%
# Pie chart for total contribution of each class in the dataset.


def plot_pie_chart(feature, df):
    data = df[feature].value_counts()
    plt.figure(figsize=(8, 8))
    plt.pie(data, labels=data.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('viridis', len(data)))
    plt.title(f'Pie Chart of {feature.replace("-", " ").capitalize()}')
    plt.show()

plot_pie_chart('class', df)

# %%
# From the above we can confirm that 54.9 % of the produce falls in class 1 and 45.1% falls in class 0.

# %%
# Histogram of all features versus class.

# Convert 'class' to string for better readability in the plot
df['class'] = df['class'].astype(str)

# List of numerical features to plot
numerical_features = ['cap-diameter', 'cap-shape', 'gill-attachment', 'gill-color', 'stem-height', 'stem-width', 'stem-color', 'season']

# Plotting histograms for each numerical feature versus class
for feature in numerical_features:
    plt.figure(figsize=(10, 6))
    sns.histplot(data=df, x=feature, hue='class', multiple="stack", palette='viridis', kde=True)
    plt.title(f'Histogram of {feature.replace("-", " ").capitalize()} vs Class')
    plt.xlabel(feature.replace("-", " ").capitalize())
    plt.ylabel('Count')
    plt.legend(title='Class')
    plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %%
categorical_features = ['cap-shape', 'gill-attachment', 'gill-color', 'stem-color', 'class']

plt.figure(figsize=(15, 12))
for i, feature in enumerate(categorical_features, 1):
    plt.subplot(3, 2, i)
    sns.countplot(x=df[feature], palette='CMRmap')
    plt.title(f'Count Plot of {feature}')
plt.tight_layout()
plt.show()

# %%
# Recalling the dataset

df
# Out:
#        cap-diameter  cap-shape  gill-attachment  gill-color  stem-height  \
# 0              1372          2                2          10     3.807467
# 1              1461          2                2          10     3.807467
# 2              1371          2                2          10     3.612496
# 3              1261          6                2          10     3.787572
# 4              1305          6                2          10     3.711971
# ...             ...        ...              ...         ...          ...
# 54030            73          5                3           2     0.887740
# 54031            82          2                3           2     1.186164
# 54032            82          5                3           2     0.915593
# 54033            79          2                3           2     1.034963
# 54034            72          5                3           2     1.158311
#
#        stem-width  stem-color    season class
# ...

# %%
# Segregating the Dataset into Input(x) and Output(y)

x=df.drop('class', axis=1).values
x
# Out:
# array([[1.37200000e+03, 2.00000000e+00, 2.00000000e+00, ...,
#         1.54500000e+03, 1.10000000e+01, 1.80427271e+00],
#        [1.46100000e+03, 2.00000000e+00, 2.00000000e+00, ...,
#         1.55700000e+03, 1.10000000e+01, 1.80427271e+00],
#        [1.37100000e+03, 2.00000000e+00, 2.00000000e+00, ...,
#         1.56600000e+03, 1.10000000e+01, 1.80427271e+00],
#        ...,
#        [8.20000000e+01, 5.00000000e+00, 3.00000000e+00, ...,
#         5.84000000e+02, 1.20000000e+01, 8.88450288e-01],
#        [7.90000000e+01, 2.00000000e+00, 3.00000000e+00, ...,
#         4.91000000e+02, 1.20000000e+01, 8.88450288e-01],
#        [7.20000000e+01, 5.00000000e+00, 3.00000000e+00, ...,
#         4.92000000e+02, 1.20000000e+01, 8.88450288e-01]])

# %%
y=df['class'].values
y
# Out:
# array(['1', '1', '1', ..., '1', '1', '1'], dtype=object)

# %%
x.shape, y.shape
# Out:
# ((54035, 8), (54035,))

# %%
# Scaling the features of the dataset

# %%
# We import additional libraries

from sklearn.preprocessing import StandardScaler
print('Importing is done')
# Out:
# Importing is done

# %%
scaler = StandardScaler()
scaler
# Out:
# StandardScaler()

# %%
# Splitting the Dataset into Training and Testing Data

# %%
# we import additional libraries

from sklearn.model_selection import train_test_split
print('Importing is done')
# Out:
# Importing is done

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=33)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((43228, 8), (10807, 8), (43228,), (10807,))

# %%
# Loading the Gaussian Naive Bayes classifier model

# %%
# We import additional libraries

from sklearn.naive_bayes import GaussianNB
print('Importing is done')
# Out:
# Importing is done

# %%
gnb = GaussianNB()
gnb
# Out:
# GaussianNB()

# %%
# We fit the training data in our model

gnb.fit(x_train, y_train)
gnb
# Out:
# GaussianNB()

# %%
# Now testing new Model prediction by providing Test Data set

y_pred = gnb.predict(x_test)
y_pred
# Out:
# array(['0', '0', '0', ..., '1', '1', '0'], dtype='<U1')

# %%
y_test
# Out:
# array(['1', '0', '0', ..., '0', '1', '0'], dtype=object)

# %%
# Calculating the Accuracy of the Trained Models

# %%
# We import additional libraries

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
print('Importing is done')
# Out:
# Importing is done

# %%
# Now we check for accuracy of test data vs training data

accuracy = accuracy_score(y_test, y_pred)
print('Model accuracy : {0:0.3f}'. format (accuracy))
np.round(accuracy,2)*100
# Out:
# Model accuracy : 0.646
# 65.0

# %%
# Generate a detailed classification report

report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.55      0.59      4968
#            1       0.66      0.72      0.69      5839
#
#     accuracy                           0.65     10807
#    macro avg       0.64      0.64      0.64     10807
# weighted avg       0.64      0.65      0.64     10807

# %%
# We can see that our model executes with a 65% accuracy for this dataset.

# %%
# Generate confusion matrix 

cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[2745 2223]
#  [1606 4233]]

# %%
# If we keep split as 70/30
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.3,random_state=33)
gnb.fit(x_train, y_train)
y_pred = gnb.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
np.round(accuracy,2)*100
# Out:
# 64.0

# %%
# Changing the variables for the split gives us low accuracy. hence 80/20 split is best for this dataset.

# %%
# Predicting the Output of Single Test Data using the Trained Model

y_test
# Out:
# array(['1', '0', '0', ..., '1', '1', '0'], dtype=object)

# %%
x_test
# Out:
# array([[7.86000000e+02, 4.00000000e+00, 2.00000000e+00, ...,
#         1.26100000e+03, 1.10000000e+01, 9.43194554e-01],
#        [8.45000000e+02, 3.00000000e+00, 0.00000000e+00, ...,
#         2.55200000e+03, 6.00000000e+00, 8.88450288e-01],
#        [2.89000000e+02, 2.00000000e+00, 0.00000000e+00, ...,
#         2.26000000e+02, 6.00000000e+00, 2.73721331e-02],
#        ...,
#        [2.15000000e+02, 5.00000000e+00, 1.00000000e+00, ...,
#         7.21000000e+02, 1.10000000e+01, 9.43194554e-01],
#        [3.53000000e+02, 2.00000000e+00, 6.00000000e+00, ...,
#         4.27000000e+02, 3.00000000e+00, 9.43194554e-01],
#        [8.79000000e+02, 2.00000000e+00, 5.00000000e+00, ...,
#         2.04000000e+03, 1.00000000e+01, 1.80427271e+00]])

# %%
# Select a single test data point from x_test

test_index = 2 
x_test_single = x_test[test_index].reshape(1, -1)

# Getting the true value for the selected test data point from y_test
true_value = y_test[test_index]

# Using the trained model to predict the value for the single test data point
predicted_value = gnb.predict(x_test_single)

print('Prediction is done')
# Out:
# Prediction is done

# %%
print('RESULTS :')
print("x_test[2]", x_test_single)
print("y_test[2]", true_value)
print("y_pred[2]", predicted_value)
# Out:
# RESULTS :
# x_test[2] [[2.89000000e+02 2.00000000e+00 0.00000000e+00 3.00000000e+00
#   8.83761250e-01 2.26000000e+02 6.00000000e+00 2.73721331e-02]]
# y_test[2] 0
# y_pred[2] ['0']

# %%
# Conclusion:
# Our model is able to perform well for the above dataset.
